# %%
from pythreejs import *
from IPython.display import display
from math import pi

# %%
BoxGeometry(
    width=5,
    height=10,
    depth=15,
    widthSegments=5,
    heightSegments=10,
    depthSegments=15)
# Out:
# Preview(child=BoxGeometry(depth=15.0, depthSegments=15, height=10.0, heightSegments=10, width=5.0, widthSegmen…

# %%
import pythreejs

# %%
pythreejs.__dict__
# Out:
# {'__name__': 'pythreejs',
#  '__doc__': None,
#  '__package__': 'pythreejs',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x7f2b84518da0>,
#  '__spec__': ModuleSpec(name='pythreejs', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f2b84518da0>, origin='/home/efefer/mysoftwares/anaconda3/lib/python3.6/site-packages/pythreejs/__init__.py', submodule_search_locations=['/home/efefer/mysoftwares/anaconda3/lib/python3.6/site-packages/pythreejs']),
#  '__path__': ['/home/efefer/mysoftwares/anaconda3/lib/python3.6/site-packages/pythreejs'],
#  '__file__': '/home/efefer/mysoftwares/anaconda3/lib/python3.6/site-packages/pythreejs/__init__.py',
#  '__cached__': '/home/efefer/mysoftwares/anaconda3/lib/python3.6/site-packages/pythreejs/__pycache__/__init__.cpython-36.pyc',
#  '__builtins__': {'__name__': 'builtins',
# ...
